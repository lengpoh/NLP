# %% [markdown]
# # Topic Modelling with LDA
#
# ####

# %% [markdown]
# #### For illustration only

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
documents = ["cat eat rice", "secret message", "today go shopping"]
tf_vectorizer = CountVectorizer()
tf_vectorized_documents = tf_vectorizer.fit_transform(documents)
tf_feature_names = tf_vectorizer.get_feature_names()

no_topics = 10
lda_model = LatentDirichletAllocation(n_components=no_topics)
lda_output = lda_model.fit_transform(tf_vectorized_documents)
lda_components = lda_model.components_

# %% [markdown]
# ###  Import the neccessary libraries
# - LDA works only with bag of words approach only
# - Regular expressions re, gensim and spacy are used to process texts.
# - PyLDAvis and matplotlib for visualization and numpy
# - Pandas for manipulating and viewing data in tabular format.

# %%
# Sklearn
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.datasets import fetch_20newsgroups

# 
import numpy as np
import pandas as pd
import re, nltk


# Plotting tools
import pyLDAvis
import pyLDAvis.sklearn
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# C:\Users\David\Anaconda3\lib\site-packages\past\builtins\misc.py:4: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import Mapping

# %% [markdown]
# #### display_topic() is a commonly used function to display topics and related terms
# - model - the lda model
# - feature_names - the features names
# - no_top_words - how many terms to display
#
# ** Do not change this function **

# %%
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print ("Topic %d:" % (topic_idx))
        print (" ".join([feature_names[i]
                        for i in topic.argsort()[:-no_top_words - 1:-1]]))

# %% [markdown]
# #### Function for Data Cleaning
# - Clean_documents() is a function to perform data cleansing for a raw document
# - This is a snub function for now. When you prepare your own set of data, you will write your own pre-processing logic

# %%
def clean_documents(document):
    # placeholder: Write data preparation codes here
    
    return document

# %% [markdown]
# ###  Data Processing
#
# #### This is the section to modify if you have other sources
# - Load in the documents from its source
# - The LDA topic model algorithm requires a document word matrix as the main input.
# - Vectorise the document using count vectorizing
# - LDA can only use raw term counts for LDA because it is a probabilistic graphical model

# %%
dataset = fetch_20newsgroups(shuffle=True, random_state=1, remove=('headers', 'footers', 'quotes'))
documents = clean_documents(dataset.data)

no_features = 1000
tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2, max_features=no_features, stop_words='english')
tf_vectorized_documents = tf_vectorizer.fit_transform(documents)
tf_feature_names = tf_vectorizer.get_feature_names()

# %% [markdown]
# #### Create the LDA model and apply LDA to the corpus of document
# - Fit and transform the vectorize document (tf)
# - Display the model attributes
# - Displays the topics terms
# - Since most cells contain zeros, the result (lda_model) will be in the form of a sparse matrix to save memory

# %%
no_topics = 10    # this s just a wild guess
lda_model = LatentDirichletAllocation(n_components=no_topics, max_iter=5, learning_method='online', learning_offset=50.,random_state=0)
lda_output = lda_model.fit_transform(tf_vectorized_documents)

print(lda_model)  # To look at the modelModel attributes
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#                           evaluate_every=-1, learning_decay=0.7,
#                           learning_method='online', learning_offset=50.0,
#                           max_doc_update_iter=100, max_iter=5,
#                           mean_change_tol=0.001, n_components=10, n_jobs=None,
#                           perp_tol=0.1, random_state=0, topic_word_prior=None,
#                           total_samples=1000000.0, verbose=0)

# %% [markdown]
# ### Preview the terms of each topic
# - Displays the topics terms

# %%
no_top_words = 20
display_topics(lda_model, tf_feature_names, no_top_words)
# Out:
# Topic 0:
# people gun armenian armenians war turkish states israel said children jews 000 state new guns israeli vs military years american
# Topic 1:
# government people law mr use president don think right public make state going privacy private security know new rights want
# Topic 2:
# space program output entry data nasa use science research build section center launch time high earth year rules long satellite
# Topic 3:
# key car chip used keys bike use bit clipper number phone like cars just engine ground des algorithm good secret
# Topic 4:
# edu file com available mail ftp files information image send list use version server email pub software cs code window
# Topic 5:
# god people does jesus say think believe don know just way like true question life time christian did point bible
# Topic 6:
# windows use drive thanks does problem know card like using db scsi dos disk bit need pc memory mac work
# Topic 7:
# ax max b8f g9v a86 pl 145 1d9 0t 34u 1t 3t giz bhj wm 2di 75u 2tm cx bxn
# Topic 8:
# just don like think know good time ve people said year did didn got ll going way game really team
# Topic 9:
# 10 00 25 15 12 20 11 14 17 16 13 30 24 50 18 19 27 40 21 new

# %% [markdown]
# ### Finding dominate topics for a document
# - To classify a document as belonging to a particular topic, a logical approach is to see which topic has the highest contribution to that document and assign it.

# %%
# column names
topicnames = ["Topic" + str(i) for i in range(lda_model.n_components)]

# index names
docnames = ["Doc" + str(i) for i in range(len(documents))]

# Make the pandas dataframe
df_document_topic = pd.DataFrame(np.round(lda_output, 2), columns=topicnames, index=docnames)

# Get dominant topic for each document
dominant_topic = np.argmax(df_document_topic.values, axis=1)
df_document_topic['dominant_topic'] = dominant_topic

# Styling
def color_green(val):
    color = 'green' if val > .1 else 'black'
    return 'color: {col}'.format(col=color)

def make_bold(val):
    weight = 700 if val > .1 else 400
    return 'font-weight: {weight}'.format(weight=weight)

# Apply Style to first 25 document
df_document_topic2 = df_document_topic.head(25).style.applymap(color_green).applymap(make_bold)
df_document_topic2
# Out:
# <style  type="text/css" >
#     #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row0_col0 {
#             color:  green;
#             font-weight:  700;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row0_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row0_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row0_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row0_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row0_col5 {
#             color:  green;
#             font-weight:  700;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row0_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row0_col7 {
#             color:  black;
#             font-weight:  400;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row0_col8 {
#             color:  green;
#             font-weight:  700;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row0_col9 {
#             color:  black;
#             font-weight:  400;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row0_col10 {
#             color:  black;
#             font-weight:  400;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row1_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row1_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row1_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row1_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row1_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row1_col5 {
#             color:  green;
#             font-weight:  700;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row1_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row1_col7 {
#             color:  black;
#             font-weight:  400;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row1_col8 {
#             color:  green;
#             font-weight:  700;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row1_col9 {
#             color:  black;
#             font-weight:  400;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row1_col10 {
#             color:  green;
#             font-weight:  700;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row2_col0 {
#             color:  green;
#             font-weight:  700;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row2_col1 {
#             color:  green;
#             font-weight:  700;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row2_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row2_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row2_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row2_col5 {
#             color:  black;
#             font-weight:  400;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row2_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row2_col7 {
#             color:  black;
#             font-weight:  400;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row2_col8 {
#             color:  green;
#             font-weight:  700;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row2_col9 {
#             color:  black;
#             font-weight:  400;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row2_col10 {
#             color:  green;
#             font-weight:  700;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row3_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row3_col1 {
#             color:  green;
#             font-weight:  700;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row3_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row3_col3 {
#             color:  green;
#             font-weight:  700;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row3_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row3_col5 {
#             color:  black;
#             font-weight:  400;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row3_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row3_col7 {
#             color:  black;
#             font-weight:  400;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row3_col8 {
#             color:  green;
#             font-weight:  700;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row3_col9 {
#             color:  black;
#             font-weight:  400;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row3_col10 {
#             color:  green;
#             font-weight:  700;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row4_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row4_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row4_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row4_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row4_col4 {
#             color:  green;
#             font-weight:  700;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row4_col5 {
#             color:  green;
#             font-weight:  700;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row4_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row4_col7 {
#             color:  black;
#             font-weight:  400;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row4_col8 {
#             color:  green;
#             font-weight:  700;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row4_col9 {
#             color:  black;
#             font-weight:  400;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row4_col10 {
#             color:  green;
#             font-weight:  700;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row5_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row5_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row5_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row5_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row5_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row5_col5 {
#             color:  green;
#             font-weight:  700;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row5_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row5_col7 {
#             color:  black;
#             font-weight:  400;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row5_col8 {
#             color:  green;
#             font-weight:  700;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c06209row5_col9 {
#             color:  black;
#             font-weight:  400;
#         }    #T_a7f38888_5c35_11ea_9e4e_a434d9c0

# %% [markdown]
# ### Question: Inspect the content of the documents
#
# - Visually look for a document with a dominant topic > 0.6 ( doc 14/topic 6 , doc 18/topic 3)
# - Use the document number to access the original corpus
# - prints the related document / text

# %%
# TO DO:
# your codes

# %% [markdown]
# ### Optional Question:
# - If we want the table above to assign a different color (e.g. red) to documents with topics weight of 0.5, what code changes are needed?

# %% [markdown]
# ### Optional Question:
# * Having topics named as topic0, topic1 etc isn't helpful in a real application. Discuss several possible ways to assign meaningful names to the row header.

# %% [markdown]
# #### Reference:
# - www.machinelearningplus.com/nlp/topic-modeling-python-sklearn-examples/
